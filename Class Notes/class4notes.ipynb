# %%
def greet(lang):
    if lang == 'es':
        print('Hola')
    if lang == 'fr':
        print('Bonjour')
    else:
        print('Hello')
greet('es')
greet('fr')
greet('en')

def greet():
    return("Hello")
print(greet(), "Glenn")
print(greet(), "Sally")

def greet(lang):
    if lang == 'es':
        
def addtwo(a, b):
    added = a + b
    return added
x = addtwo(3, 5)
print(x)

def make_sandwhich(meat, cheese = 'cheddar', bread = ' rye')
    print('Ill have a sanwhich with ', meat, cheese, 'and', bread, ' bread.')

make_sandwhich('ham')
make_sandwhich('spam')
make_sandwhich('spam', 'cream cheese')

def printall(*args):
    print(*args)

printall(1,3,'hi')
printall('Hello', 'Welcome')

def sqr(x):
    if x<0:
        print('No root of a negative number')
        return None
    if x == 0:
        return 0
    start = 0
    limit = 100
    for i in range(start,limit,1):
        if i*i == x:
            return i
        if i*i>x:
            start = i-1
            limit = i
            for j in range(start*10,limit*10,1):
                k = j/10
                if k*k == x:
                    return k
                if k*k>x:
                    return k
print(sqr(15))
           
def triangle(base,height):
    if base < 0:
        print("cannot have negative length")
        return None
    if height < 0:
        print('cannot have negative length')
        return None
    area = (base/2)*height
    return area
print('The area of a 2 by 5 triangle is ', triangle(2,5))

def foo(x,y):
    global a
    a = 5
    b = 10
    x,y=y,x
    print('\ninside foo')
    print('a=',a,'\nb=',b,'\nx=',x,'\ny=',y)
a=1
b=2
x=3
y=4
print('\nbefore calling foo')
print('a=',a,'\nb=',b,'\nx=',x,'\ny=',y)
foo(25,30)
print('\nafter calling foo')
print('a=',a,'\nb=',b,'\nx=',x,'\ny=',y)

def test_func(n):
    x=n**2
    print(x)
    print(y)
    return None
x=5
y=6
print(x)
test_func(5)
print(x)

import math
x = math.sqrt(16)
print(x)

import math as mth
x=mth.sqrt(16)
print(x)

import matplotlib.pyplot as plt
x = range(100)
y= [number**2 for number in x]
plt.plot(x,y)
plt.show

x = [1,2,3,4,5]
y=[12,24,0,9,15]
plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(2,2,2)
plt.scatter(x,y)

plt.subplot(2,2,3)
plt.bar(x,y)

plt.subplot(2,2,4)
plt.pie(y)

plt.show()

import numpy as np
# Out:
#   File "<ipython-input-1-711662c7fed3>", line 20
#     def addtwo(a, b):
#                      ^
# IndentationError: expected an indented block

# %%
import matplotlib.pyplot as plt
x = range(100)
y= [number**2 for number in x]
plt.plot(x,y)
plt.show

x = [1,2,3,4,5]
y=[12,24,0,9,15]
plt.subplot(2,2,1)
plt.plot(x,y)

plt.subplot(2,2,2)
plt.scatter(x,y)

plt.subplot(2,2,3)
plt.bar(x,y)

plt.subplot(2,2,4)
plt.pie(y)

plt.show()
