# %%
import numpy as np
import pandas as pd

# %%
data = pd.read_csv('endangeredLang2.csv')
data.head()
# Out:
#      ID   EnglishNames                                          Countries  \
# 0  1022  South Italian                                              Italy
# 1  1023       Sicilian                                              Italy
# 2   383      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382        Lombard                                 Italy, Switzerland
#
#                     CountryCode           Endangerment         No  Latitude  \
# 0                           ITA             Vulnerable  7500000.0   40.9798
# 1                           ITA             Vulnerable  5000000.0   37.4399
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable  4800000.0   53.4029
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable  4000000.0   53.9560
# 4                      ITA, CHE  Definitely endangered  3500000.0   45.7215
#
#    Longitude
# 0    15.2490
# 1    14.5019
# 2    10.3601
# ...

# %%
df  = data [['Countries' , 'CountryCode']] # isolating two columns
df.head()
# Out:
#                                            Countries  \
# 0                                              Italy
# 1                                              Italy
# 2  Germany, Denmark, Netherlands, Poland, Russian...
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
#
#                     CountryCode
# 0                           ITA
# 1                           ITA
# 2       DEU, DNK, NLD, POL, RUS
# 3  BRB, LVA, LTU, POL, RUS, UKR
# 4                      ITA, CHE

# %%
data [3:10]
# Out:
#      ID                 EnglishNames  \
# 3   335                   Belarusian
# 4   382                      Lombard
# 5   405                       Romani
# 6  2211             Yiddish (Israel)
# 7  1586                        Gondi
# 8  1020         Limburgian-Ripuarian
# 9  1943  Quechua of Southern Bolivia
#
#                                            Countries  \
# 3  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4                                 Italy, Switzerland
# 5  Albania, Germany, Austria, Belarus, Bosnia and...
# 6                                             Israel
# 7                                              India
# 8                      Germany, Belgium, Netherlands
# 9                   Bolivia (Plurinational State of)
#
#                                          CountryCode           Endangerment  \
# 3                       BRB, LVA, LTU, POL, RUS, UKR             Vulnerable
# 4                                           ITA, CHE  Definitely endangered
# ...

# %%
df = data[data['No'] < 5000]
df.head(6)
# Out:
#        ID       EnglishNames           Countries CountryCode  \
# 740  1125              Jirel               Nepal         NPL
# 741   468             Dolgan  Russian Federation         RUS
# 742  2057  Romani (Colombia)            Colombia         COL
# 743  1160               Tsum               Nepal         NPL
# 744   993  Northern Tlapanec              Mexico         MEX
# 745  2028             Taroko               China         CHN
#
#               Endangerment      No  Latitude  Longitude
# 740  Definitely endangered  4919.0   27.6419    86.2123
# 741  Definitely endangered  4865.0   71.3851    97.3388
# 742             Vulnerable  4858.0       NaN        NaN
# 743  Definitely endangered  4786.0   28.4723    85.0080
# 744             Vulnerable  4771.0   17.4203   -98.7814
# 745             Vulnerable  4750.0   24.0916   121.5218

# %%
df.drop(['Endangerment'], axis = 1, inplace = True)
df.head()
# Out:
# C:\Users\razie\Anaconda3\lib\site-packages\pandas\core\frame.py:3940: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   errors=errors)
#        ID       EnglishNames           Countries CountryCode      No  \
# 740  1125              Jirel               Nepal         NPL  4919.0
# 741   468             Dolgan  Russian Federation         RUS  4865.0
# 742  2057  Romani (Colombia)            Colombia         COL  4858.0
# 743  1160               Tsum               Nepal         NPL  4786.0
# 744   993  Northern Tlapanec              Mexico         MEX  4771.0
#
#      Latitude  Longitude
# 740   27.6419    86.2123
# 741   71.3851    97.3388
# 742       NaN        NaN
# 743   28.4723    85.0080
# 744   17.4203   -98.7814

# %%
data.iloc [ 0:8 , 0:6]
# Out:
#      ID      EnglishNames                                          Countries  \
# 0  1022     South Italian                                              Italy
# 1  1023          Sicilian                                              Italy
# 2   383         Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335        Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382           Lombard                                 Italy, Switzerland
# 5   405            Romani  Albania, Germany, Austria, Belarus, Bosnia and...
# 6  2211  Yiddish (Israel)                                             Israel
# 7  1586             Gondi                                              India
#
#                                          CountryCode           Endangerment  \
# 0                                                ITA             Vulnerable
# 1                                                ITA             Vulnerable
# ...

# %%
data.loc [ : , ['ID','Countries']]
# Out:
#         ID                                          Countries
# 0     1022                                              Italy
# 1     1023                                              Italy
# 2      383  Germany, Denmark, Netherlands, Poland, Russian...
# 3      335  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4      382                                 Italy, Switzerland
# 5      405  Albania, Germany, Austria, Belarus, Bosnia and...
# 6     2211                                             Israel
# 7     1586                                              India
# 8     1020                      Germany, Belgium, Netherlands
# 9     1943                   Bolivia (Plurinational State of)
# 10    1565                                       India, Nepal
# 11     755      Bolivia (Plurinational State of), Chile, Peru
# 12     349                                  Italy, San Marino
# 13     399                                              Italy
# ...

# %%
data [[ 'Countries', 'EnglishNames']][4:8]
# Out:
#                                            Countries      EnglishNames
# 4                                 Italy, Switzerland           Lombard
# 5  Albania, Germany, Austria, Belarus, Bosnia and...            Romani
# 6                                             Israel  Yiddish (Israel)
# 7                                              India             Gondi

# %%
data [data.Countries == 'Netherlands']
# Out:
#      ID  EnglishNames    Countries CountryCode Endangerment        No  \
# 87  426  West Frisian  Netherlands         NLD   Vulnerable  350000.0
#
#     Latitude  Longitude
# 87   53.1006     5.6579

# %%
x = data.loc [ data ['Countries'].isin( [ 'Netherlands', 'Germany'])] # isolated/ subset by more than 1 especific value in a column
x.head()
# Out:
#        ID   EnglishNames    Countries CountryCode           Endangerment  \
# 87    426   West Frisian  Netherlands         NLD             Vulnerable
# 406   384        Sorbian      Germany         DEU  Definitely endangered
# 534   394  North Frisian      Germany         DEU    Severely endangered
# 1208  346    Saterlandic      Germany         DEU    Severely endangered
# 2470  403       Polabian      Germany         DEU                Extinct
#
#             No  Latitude  Longitude
# 87    350000.0   53.1006     5.6579
# 406    19500.0   51.5001    14.4744
# 534    10000.0   54.7341     8.7478
# 1208    1000.0   53.1059     7.6787
# 2470       0.0   53.0940    11.3461

# %%
data.sort_values(by = 'No', ascending = False ) # sorting a column in a desending order(max to min)
data.head()
# Out:
#      ID   EnglishNames                                          Countries  \
# 0  1022  South Italian                                              Italy
# 1  1023       Sicilian                                              Italy
# 2   383      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382        Lombard                                 Italy, Switzerland
#
#                     CountryCode           Endangerment         No  Latitude  \
# 0                           ITA             Vulnerable  7500000.0   40.9798
# 1                           ITA             Vulnerable  5000000.0   37.4399
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable  4800000.0   53.4029
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable  4000000.0   53.9560
# 4                      ITA, CHE  Definitely endangered  3500000.0   45.7215
#
#    Longitude
# 0    15.2490
# 1    14.5019
# 2    10.3601
# ...

# %%
data.sort_values(by = 'No', ascending = True ) # sorting a column in a ascending order
data.head()
# Out:
#      ID   EnglishNames                                          Countries  \
# 0  1022  South Italian                                              Italy
# 1  1023       Sicilian                                              Italy
# 2   383      Low Saxon  Germany, Denmark, Netherlands, Poland, Russian...
# 3   335     Belarusian  Belarus, Latvia, Lithuania, Poland, Russian Fe...
# 4   382        Lombard                                 Italy, Switzerland
#
#                     CountryCode           Endangerment         No  Latitude  \
# 0                           ITA             Vulnerable  7500000.0   40.9798
# 1                           ITA             Vulnerable  5000000.0   37.4399
# 2       DEU, DNK, NLD, POL, RUS             Vulnerable  4800000.0   53.4029
# 3  BRB, LVA, LTU, POL, RUS, UKR             Vulnerable  4000000.0   53.9560
# 4                      ITA, CHE  Definitely endangered  3500000.0   45.7215
#
#    Longitude
# 0    15.2490
# 1    14.5019
# 2    10.3601
# ...

# %%
data['Endangerment'].value_counts()
# Out:
# Definitely endangered    680
# Vulnerable               628
# Critically endangered    607
# Severely endangered      554
# Extinct                  253
# Name: Endangerment, dtype: int64

# %%
data['Endangerment'].count()
# Out:
# 2722

# %%
data['No'].max()
# Out:
# 7500000.0

# %%
data['No'].min()
# Out:
# 0.0

# %%
data['No'].mean()
# Out:
# 53658.9038991729

# %%
data['No'].std()
# Out:
# 311462.02741730167

# %%
data['No'].var()
# Out:
# 97008594522.89598

# %%
data['No'].describe()
# Out:
# count    2.539000e+03
# mean     5.365890e+04
# std      3.114620e+05
# min      0.000000e+00
# 25%      5.000000e+01
# 50%      8.000000e+02
# 75%      6.872000e+03
# max      7.500000e+06
# Name: No, dtype: float64

# %%
bystatus = data.groupby('Endangerment') # grouping data based on comon factor/cluster
bystatus.head()
# Out:
#         ID            EnglishNames  \
# 0     1022           South Italian
# 1     1023                Sicilian
# 2      383               Low Saxon
# 3      335              Belarusian
# 4      382                 Lombard
# 5      405                  Romani
# 6     2211        Yiddish (Israel)
# 7     1586                   Gondi
# 12     349        Emilian-Romagnol
# 13     399             Piedmontese
# 48     398                  Picard
# 62     375            Languedocian
# 77    2165        Judezmo (Israel)
# 79     378                Limousin
# 104    336                  Breton
# 232   1587                   Parji
# 250   2180                Zenatiya
# 307   1490                    Mayo
# 310   1561                Sirmaudi
# 332   2181                Tidikelt
# 485   2618                 Tobada'
# 1040  2059  Tamazight (Ait Rouadi)
# 2221   580               Canichana
# 2269  2112                     Lae
# 2277   661                     Uru
#
# ...

# %%
bystatus.sum()
# Out:
#                            ID          No    Latitude   Longitude
# Endangerment
# Critically endangered  805324    501388.0   8399.2923   9800.4274
# Definitely endangered  947228  39503297.0  12849.6351  21077.1344
# Extinct                279587     13642.0   4832.1746   2590.4871
# Severely endangered    712108   5226486.0   9948.5089  13028.4187
# Vulnerable             964481  90995144.0   8148.3001  14044.8200

# %%
bystatus.describe()
# Out:
#                           ID                                                  \
#                        count         mean         std   min      25%     50%
# Endangerment
# Critically endangered  607.0  1326.728171  820.100236   2.0   582.50  1394.0
# Definitely endangered  680.0  1392.982353  752.891226   6.0   743.75  1344.0
# Extinct                253.0  1105.086957  843.512215   4.0   447.00   822.0
# Severely endangered    554.0  1285.393502  789.629123   3.0   533.00  1346.5
# Vulnerable             628.0  1535.797771  718.614862  19.0  1067.75  1542.5
#
#                                            No                 ...   Latitude  \
#                            75%     max  count           mean  ...        75%
# Endangerment                                                  ...
# Critically endangered  2074.50  2724.0  544.0     921.669118  ...  34.713075
# Definitely endangered  2019.75  2723.0  635.0   62209.916535  ...  34.428900
# ...

# %%
bystatus.std()
# Out:
#                                ID             No   Latitude   Longitude
# Endangerment
# Critically endangered  820.100236    4358.645710  25.152414  100.734527
# Definitely endangered  752.891226  283769.657013  21.626371   84.460529
# Extinct                843.512215     774.907556  26.286156   95.866868
# Severely endangered    789.629123   50543.595134  23.636338   91.302692
# Vulnerable             718.614862  550861.482258  20.647781   92.020763

# %%
bystatus.max()
# Out:
#                          ID EnglishNames         No  Latitude  Longitude
# Endangerment
# Critically endangered  2724         ǂHoa    51216.0   71.6973   169.0740
# Definitely endangered  2723         ǁAni  3500000.0   77.4815   179.1870
# Extinct                2713       ǁXegwi    12000.0   69.2872   176.9183
# Severely endangered    2719    Émérillon   700000.0   72.8160   176.1767
# Vulnerable             2718        ǁGana  7500000.0   69.3878   177.3632

# %%
data.groupby('Endangerment').count()
# Out:
#                         ID  EnglishNames  Countries  CountryCode   No  \
# Endangerment
# Critically endangered  607           607        607          607  544
# Definitely endangered  680           680        679          679  635
# Extinct                253           253        253          253  244
# Severely endangered    554           554        554          554  505
# Vulnerable             628           628        628          628  611
#
#                        Latitude  Longitude
# Endangerment
# Critically endangered       606        606
# Definitely endangered       680        680
# Extinct                     252        252
# Severely endangered         554        554
# Vulnerable                  627        627

# %%
data.groupby(['Countries','Endangerment']).count()
# Out:
#                                                                           ID  \
# Countries                                          Endangerment
# Afghanistan                                        Critically endangered   2
#                                                    Definitely endangered   5
#                                                    Severely endangered     4
#                                                    Vulnerable              1
# Albania, Algeria, Bosnia and Herzegovina, Bulga... Severely endangered     1
# Albania, Bulgaria, Greece, The former Yugoslav ... Definitely endangered   1
# Albania, Bulgaria, The former Yugoslav Republic... Vulnerable              1
# Albania, Germany, Austria, Belarus, Bosnia and ... Definitely endangered   1
# Algeria                                            Critically endangered   3
#                                                    Severely endangered     5
# ...
